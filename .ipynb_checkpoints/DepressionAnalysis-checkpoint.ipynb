# %% [markdown]
# # Depression Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv('final_depression_dataset_1.csv')

data
# Out:
#              Name  Gender  Age       City Working Professional or Student  \
# 0           Pooja  Female   37  Ghaziabad            Working Professional
# 1         Reyansh    Male   60     Kalyan            Working Professional
# 2           Manvi  Female   42     Bhopal            Working Professional
# 3            Isha  Female   44      Thane            Working Professional
# 4           Aarav    Male   48     Indore            Working Professional
# ...           ...     ...  ...        ...                             ...
# 2551  Raghavendra    Male   25  Bangalore            Working Professional
# 2552         Pihu  Female   23       Pune            Working Professional
# 2553         Sara  Female   24   Srinagar            Working Professional
# 2554       Eshita  Female   56  Bangalore            Working Professional
# 2555        Kiran    Male   18      Surat                         Student
#
#              Profession  Academic Pressure  Work Pressure  CGPA  \
# 0               Teacher                NaN            2.0   NaN
# 1     Financial Analyst                NaN            4.0   NaN
# 2               Teacher                NaN            2.0   NaN
# 3               Teacher                NaN            3.0   NaN
# 4        UX/UI Designer                NaN            4.0   NaN
# ...                 ...                ...            ...   ...
# 2551         Consultant                NaN            1.0   NaN
# 2552            Teacher                NaN            3.0   NaN
# 2553         HR Manager                NaN            1.0   NaN
# 2554   Business Analyst                NaN            2.0   NaN
# 2555                NaN                5.0            NaN   6.7
#
#       Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 0                    NaN               4.0          7-8 hours       Moderate
# 1                    NaN               3.0          5-6 hours      Unhealthy
# 2                    NaN               3.0          5-6 hours       Moderate
# 3                    NaN               5.0          7-8 hours        Healthy
# 4                    NaN               3.0          7-8 hours       Moderate
# ...                  ...               ...                ...            ...
# 2551                 NaN               5.0          5-6 hours        Healthy
# 2552                 NaN               1.0  Less than 5 hours       Moderate
# 2553                 NaN               4.0  Less than 5 hours       Moderate
# 2554                 NaN               3.0          7-8 hours        Healthy
# 2555                 3.0               NaN  More than 8 hours      Unhealthy
#
#         Degree Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0           MA                                    No                 6
# 1        B.Com                                   Yes                 0
# 2        M.Com                                    No                 0
# 3           MD                                   Yes                 1
# 4           BE                                   Yes                 6
# ...        ...                                   ...               ...
# 2551       BBA                                   Yes                12
# 2552        MA                                   Yes                 8
# 2553        BA                                   Yes                 4
# 2554       BBA                                    No                 4
# 2555  Class 12                                    No                 6
#
#       Financial Stress Family History of Mental Illness Depression
# 0                    2                               No         No
# 1                    4                              Yes         No
# 2                    2                               No         No
# 3                    2                              Yes         No
# 4                    5                              Yes         No
# ...                ...                              ...        ...
# 2551                 3                              Yes         No
# 2552                 3                               No        Yes
# 2553                 4                               No         No
# 2554                 5                              Yes         No
# 2555                 2                              Yes        Yes
#
# [2556 rows x 19 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# Example of handling missing values without inplace=True
data['Academic Pressure'] = data['Academic Pressure'].fillna(data['Academic Pressure'].mean())
data['CGPA'] = data['CGPA'].fillna(data['CGPA'].mean())
data['Study Satisfaction'] = data['Study Satisfaction'].fillna(data['Study Satisfaction'].mean())

##convert dietary
# Example of converting categorical columns to numerical values
data['Gender'] = data['Gender'].map({'Male': 1, 'Female': 0})
data['Working Professional or Student'] = data['Working Professional or Student'].map({'Working Professional': 1, 'Student': 0})  
data['Profession'] = data['Profession'].map({'Teacher': 1, 'Engineer': 2, 'Student': 3, 'Doctor': 4})  
data['Depression'] = data['Depression'].map({'Yes': 1, 'No': 0})
data['Family History of Mental Illness'] = data['Family History of Mental Illness'].map({'Yes': 1, 'No': 0})
data['Suicidal Thoughts'] = data['Have you ever had suicidal thoughts ?'].map({'Yes': 1, 'No': 0})

# %%
import re
#data cleaning sleep duration
def parse_sleep_duration(duration):
    if isinstance(duration, str):
        # Extract numbers using regex
        numbers = re.findall(r'\d+', duration)
        if len(numbers) == 2:  # If it's a range like "7-8"
            return (int(numbers[0]) + int(numbers[1])) / 2
        elif len(numbers) == 1:  # If it's a single value like "7 hours"
            return int(numbers[0])
    return np.nan  # If the value is missing or invalid

# Apply the function
data['Sleep Duration'] = data['Sleep Duration'].apply(parse_sleep_duration)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# * Descriptive statistics like mean, median, range, correlations
# *
# Data visualizations for univariate and multivariate exploratio
# * n*
# Text explaining insights gained from exploration

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2556 entries, 0 to 2555
# Data columns (total 20 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Name                                   2556 non-null   object
#  1   Gender                                 2556 non-null   int64
#  2   Age                                    2556 non-null   int64
#  3   City                                   2556 non-null   object
#  4   Working Professional or Student        2556 non-null   int64
#  5   Profession                             388 non-null    float64
#  6   Academic Pressure                      2556 non-null   float64
#  7   Work Pressure                          2054 non-null   float64
#  8   CGPA                                   2556 non-null   float64
#  9   Study Satisfaction                     2556 non-null   float64
#  10  Job Satisfaction                       2054 non-null   float64
#  11  Sleep Duration                         2556 non-null   float64
#  12  Dietary Habits                         2556 non-null   object
#  13  Degree                                 2556 non-null   object
#  14  Have you ever had suicidal thoughts ?  2556 non-null   object
#  15  Work/Study Hours                       2556 non-null   int64
#  16  Financial Stress                       2556 non-null   int64
#  17  Family History of Mental Illness       2556 non-null   int64
#  18  Depression                             2556 non-null   int64
#  19  Suicidal Thoughts                      2556 non-null   int64
# dtypes: float64(7), int64(8), object(5)
# memory usage: 399.5+ KB
# None

# %%
print(data.describe().T)
# Out:
#                                    count       mean        std    min  \
# Gender                            2556.0   0.521518   0.499635   0.00
# Age                               2556.0  39.043036  12.260596  18.00
# Working Professional or Student   2556.0   0.803599   0.397353   0.00
# Profession                         388.0   1.510309   1.128625   1.00
# Academic Pressure                 2556.0   3.003984   0.615518   1.00
# Work Pressure                     2054.0   3.021908   1.417312   1.00
# CGPA                              2556.0   7.567809   0.648888   5.03
# Study Satisfaction                2556.0   3.075697   0.608203   1.00
# Job Satisfaction                  2054.0   3.015093   1.418432   1.00
# Sleep Duration                    2556.0   6.496479   1.273464   5.00
# Work/Study Hours                  2556.0   6.023865   3.771743   0.00
# Financial Stress                  2556.0   2.968701   1.415527   1.00
# Family History of Mental Illness  2556.0   0.487089   0.499931   0.00
# Depression                        2556.0   0.178013   0.382598   0.00
# Suicidal Thoughts                 2556.0   0.488654   0.499969   0.00
#
#                                         25%        50%        75%   max
# Gender                             0.000000   1.000000   1.000000   1.0
# Age                               28.000000  39.000000  50.000000  60.0
# Working Professional or Student    1.000000   1.000000   1.000000   1.0
# Profession                         1.000000   1.000000   1.000000   4.0
# Academic Pressure                  3.003984   3.003984   3.003984   5.0
# Work Pressure                      2.000000   3.000000   4.000000   5.0
# CGPA                               7.567809   7.567809   7.567809  10.0
# Study Satisfaction                 3.075697   3.075697   3.075697   5.0
# Job Satisfaction                   2.000000   3.000000   4.000000   5.0
# Sleep Duration                     5.000000   7.500000   7.500000   8.0
# Work/Study Hours                   3.000000   6.000000   9.000000  12.0
# Financial Stress                   2.000000   3.000000   4.000000   5.0
# Family History of Mental Illness   0.000000   0.000000   1.000000   1.0
# Depression                         0.000000   0.000000   0.000000   1.0
# Suicidal Thoughts                  0.000000   0.000000   1.000000   1.0

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# Name                                        0
# Gender                                      0
# Age                                         0
# City                                        0
# Working Professional or Student             0
# Profession                               2168
# Academic Pressure                           0
# Work Pressure                             502
# CGPA                                        0
# Study Satisfaction                          0
# Job Satisfaction                          502
# Sleep Duration                              0
# Dietary Habits                              0
# Degree                                      0
# Have you ever had suicidal thoughts ?       0
# Work/Study Hours                            0
# Financial Stress                            0
# Family History of Mental Illness            0
# Depression                                  0
# Suicidal Thoughts                           0
# dtype: int64

# %%
# Range (max - min)
data_range = data.max(numeric_only=True) - data.min(numeric_only=True)
print("Range:\n", data_range)

# Variance
data_variance = data.var(numeric_only=True)
print("Variance:\n", data_variance)

# Skewness (asymmetry of data distribution)
data_skewness = data.skew(numeric_only=True)
print("Skewness:\n", data_skewness)

# Kurtosis (tail heaviness)
data_kurtosis = data.kurt(numeric_only=True)
print("Kurtosis:\n", data_kurtosis)
# Out:
# Range:
#  Gender                               1.00
# Age                                 42.00
# Working Professional or Student      1.00
# Profession                           3.00
# Academic Pressure                    4.00
# Work Pressure                        4.00
# CGPA                                 4.97
# Study Satisfaction                   4.00
# Job Satisfaction                     4.00
# Sleep Duration                       3.00
# Work/Study Hours                    12.00
# Financial Stress                     4.00
# Family History of Mental Illness     1.00
# Depression                           1.00
# Suicidal Thoughts                    1.00
# dtype: float64
# Variance:
#  Gender                                0.249635
# Age                                 150.322218
# Working Professional or Student       0.157889
# Profession                            1.273795
# Academic Pressure                     0.378862
# Work Pressure                         2.008775
# CGPA                                  0.421056
# Study Satisfaction                    0.369911
# Job Satisfaction                      2.011949
# Sleep Duration                        1.621710
# Work/Study Hours                     14.226045
# Financial Stress                      2.003717
# Family History of Mental Illness      0.249931
# Depression                            0.146381
# Suicidal Thoughts                     0.249969
# dtype: float64
# Skewness:
#  Gender                             -0.086202
# Age                                -0.005077
# Working Professional or Student    -1.529307
# Profession                          1.762885
# Academic Pressure                  -0.026152
# Work Pressure                      -0.015083
# CGPA                               -0.069278
# Study Satisfaction                 -0.192987
# Job Satisfaction                    0.009221
# Sleep Duration                     -0.002652
# Work/Study Hours                   -0.018289
# Financial Stress                    0.042091
# Family History of Mental Illness    0.051691
# Depression                          1.684481
# Suicidal Thoughts                   0.045422
# dtype: float64
# Kurtosis:
#  Gender                             -1.994130
# Age                                -1.188594
# Working Professional or Student     0.339044
# Profession                          1.113478
# Academic Pressure                   6.103835
# Work Pressure                      -1.306958
# CGPA                                6.029552
# Study Satisfaction                  6.013465
# Job Satisfaction                   -1.309263
# Sleep Duration                     -1.852695
# Work/Study Hours                   -1.245715
# Financial Stress                   -1.308574
# Family History of Mental Illness   -1.998893
# Depression                          0.838131
# Suicidal Thoughts                  -1.999502
# dtype: float64

# %%
# Plot histograms for numeric columns
data.hist(figsize=(12, 10), bins=20)
plt.suptitle("Histograms of All Numeric Features")
plt.show()

# %%
# Boxplots for key variables
for column in data.select_dtypes(include=[np.number]).columns:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=data[column])
    plt.title(f'Boxplot for {column}')
    plt.show()

# %%
# Correlation of features with Depression
target_corr = data.select_dtypes(include=[np.number]).corr()['Depression'].sort_values(ascending=False)
print("Correlation with Depression:\n", target_corr)
# Out:
# Correlation with Depression:
#  Depression                          1.000000
# Suicidal Thoughts                   0.281669
# Academic Pressure                   0.275882
# Work Pressure                       0.197509
# Financial Stress                    0.165669
# Work/Study Hours                    0.152465
# CGPA                                0.025874
# Family History of Mental Illness    0.019182
# Gender                              0.007595
# Profession                         -0.035991
# Sleep Duration                     -0.054944
# Job Satisfaction                   -0.166880
# Study Satisfaction                 -0.170006
# Working Professional or Student    -0.418708
# Age                                -0.485147
# Name: Depression, dtype: float64

# %%
# Frequency distribution for each categorical column
categorical_columns = data.select_dtypes(include=['object', 'category']).columns
for column in categorical_columns:
    print(f"Value counts for {column}:\n", data[column].value_counts())
    print("\n")
# Out:
# Value counts for Name:
#  Name
# Rohan     26
# Tushar    26
# Sanya     24
# Kiran     20
# Ivaan     20
#           ..
# Zoya       5
# Harini     5
# Mukund     4
# Aarya      4
# Rupa       3
# Name: count, Length: 216, dtype: int64
#
#
# Value counts for City:
#  City
# Srinagar         102
# Meerut           101
# Mumbai            99
# Pune              98
# Rajkot            96
# Vasai-Virar       95
# Kalyan            92
# Ahmedabad         92
# Patna             89
# Chennai           88
# Ludhiana          88
# Vadodara          88
# Kolkata           87
# Hyderabad         85
# Agra              85
# Kanpur            84
# Visakhapatnam     84
# Varanasi          83
# Indore            82
# Bhopal            81
# Surat             80
# Jaipur            80
# Thane             80
# Nagpur            78
# Bangalore         76
# Lucknow           75
# Delhi             74
# Faridabad         73
# Nashik            73
# Ghaziabad         68
# Name: count, dtype: int64
#
#
# Value counts for Dietary Habits:
#  Dietary Habits
# Unhealthy    882
# Healthy      842
# Moderate     832
# Name: count, dtype: int64
#
#
# Value counts for Degree:
#  Degree
# Class 12    275
# B.Com       115
# B.Ed        112
# MCA         108
# BCA         103
# MSc          95
# MBA          95
# BSc          94
# BBA          92
# BHM          90
# B.Arch       89
# BA           89
# B.Pharm      88
# M.Tech       85
# M.Pharm      85
# ME           84
# LLM          84
# BE           84
# LLB          82
# PhD          81
# MHM          81
# M.Ed         81
# MA           79
# MBBS         75
# MD           74
# B.Tech       71
# M.Com        65
# Name: count, dtype: int64
#
#
# Value counts for Have you ever had suicidal thoughts ?:
#  Have you ever had suicidal thoughts ?
# No     1307
# Yes    1249
# Name: count, dtype: int64

# %%
#sns.pairplot(data, hue='Depression')  # Use 'hue' to separate by Depression status
#plt.show()

# %%
# Scatterplot of Job Satisfaction vs Sleep Duration
sns.scatterplot(x='Job Satisfaction', y='Sleep Duration', hue='Depression', data=data)
plt.title('Job Satisfaction vs Sleep Duration')
plt.show()

# %%
# Save descriptive statistics to a CSV file
descriptive_stats = data.describe().T
descriptive_stats['Range'] = data_range
descriptive_stats['Variance'] = data_variance
descriptive_stats['Skewness'] = data_skewness
descriptive_stats['Kurtosis'] = data_kurtosis

descriptive_stats.to_csv('descriptive_statistics.csv')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# * Descriptive statistics like mean, median, range, correlations
# *
# Data visualizations for univariate and multivariate exploratio
# * n*
# Text explaining insights gained from exploration

# %%
# Select numeric columns for correlation analysis
numeric_data = data.select_dtypes(include=[np.number])

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Boxplot to detect outliers in numerical features
for column in numeric_data.columns:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=data[column])
    plt.title(f'Outliers in {column}')
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_depression_by_category(data, category_column):
    # Calculate depression percentage for each category in the specified column
    depression_percentage = data.groupby(category_column)['Depression'].mean().sort_values(ascending=False)
    
    # Get the ordered categories
    category_order = depression_percentage.index
    
    # Create the plot
    plt.figure(figsize=(12, 8))
    sns.countplot(y=category_column, hue='Depression', data=data, palette="viridis", order=category_order)
    plt.legend(title="Depression", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.title(f'Depression by {category_column} (Ordered by Depression Percentage)')
    plt.show()

# %%
# List of categorical columns you want to analyze
categorical_columns = ['Degree', 'Profession','Dietary Habits','Have you ever had suicidal thoughts ?','City']  # Add more as needed

# Loop through each categorical column and generate the plot
for column in categorical_columns:
    plot_depression_by_category(data, column)

# %%
# Distribution of depression by gender
sns.countplot(x='Depression', hue='Gender', data=data)
plt.title('Depression by Gender')
plt.show()

# Distribution of depression by age groups
data['Age Group'] = pd.cut(data['Age'], bins=[18, 25, 35, 45, 55, 65], labels=['18-25', '26-35', '36-45', '46-55', '56-65'])
sns.countplot(x='Depression', hue='Age Group', data=data)
plt.title('Depression by Age Group')
plt.show()

# %%
# Crosstab heatmap
crosstab = pd.crosstab(data['Depression'], data['Gender'])
sns.heatmap(crosstab, annot=True, fmt='d', cmap='coolwarm')
plt.title('Depression by Gender')
plt.show()

# %%
# Histograms for all numerical features
data.hist(figsize=(12, 10), bins=20, color='lightblue', edgecolor='black')
plt.suptitle('Histograms of Numerical Variables')
plt.show()

# %%
sns.violinplot(x='Depression', y='Job Satisfaction', data=data)
plt.title('Job Satisfaction by Depression Status')
plt.show()

# %% [markdown]
# ## Feature Selection
# ### Identifying most relevant variables

# %%
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.impute import SimpleImputer

# Impute remaining missing values
imputer = SimpleImputer(strategy='mean')
numeric_data = pd.DataFrame(imputer.fit_transform(numeric_data), columns=numeric_data.columns)

# Define features and target
X = numeric_data.drop(['Depression'], axis=1)
y = numeric_data['Depression']

# SelectKBest for top 10 features
best_features = SelectKBest(score_func=chi2, k=10).fit(X, y)
feature_scores = pd.DataFrame({'Feature': X.columns, 'Score': best_features.scores_})
feature_scores = feature_scores.sort_values(by='Score', ascending=False)
print(feature_scores)
# Out:
#                              Feature        Score
# 1                                Age  2315.350399
# 10                  Work/Study Hours   140.261678
# 13                 Suicidal Thoughts   103.693672
# 2    Working Professional or Student    88.008849
# 11                  Financial Stress    47.330547
# 5                      Work Pressure    26.039738
# 4                  Academic Pressure    24.525683
# 8                   Job Satisfaction    18.661250
# 7                 Study Satisfaction     8.881234
# 9                     Sleep Duration     1.925443
# 12  Family History of Mental Illness     0.482395
# 6                               CGPA     0.095167
# 0                             Gender     0.070541
# 3                         Profession     0.033190

# %% [markdown]
# ## Detect Outliers and Anomalies Using Isolation Forest

# %% [markdown]
# ### Final Insights and Optimization
# ##### After building the model and evaluating feature importance, analyze findings for the most influential factors contributing to depression and highlight any patterns or anomalies. This comprehensive approach maximizes insights into the dataset, extracts important features, and ensures a well-rounded understanding of the underlying structure, facilitating evidence-based decisions or further research.
